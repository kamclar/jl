# %%
import numpy as np
import pandas as pd

# %%
url = 'https://github.com/kamclar/demo/tree/main/content/data/VEGF2_ChEMBL28_10980_pic50.csv'
df = pd.read_csv(url)
df.head()
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 url = 'https://github.com/kamclar/demo/tree/main/content/data/VEGF2_ChEMBL28_10980_pic50.csv'
# ----> 2 df = pd.read_csv(url)
#       3 df.head()
#
# File /lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
